# %% [markdown]
# # Cat Affinity Data

# %%
import ipywidgets as widgets
from ipywidgets import interact_manual,interact, Dropdown
import pandas as pd

# Load the cataffinity data into a pandas DataFrame
cataffinity = pd.read_csv(r'C:\Users\Mohij\OneDrive\Desktop\combined_data.csv', low_memory=False)

# Define a dictionary that maps each column name to a list of its unique values
column_values = {'feature': list(cataffinity['feature'].unique()),
                 'rropcf': list(cataffinity['rropcf'].unique())}
filtered_data = None
def filter_data(column, x, Column_2, Y):
    filtered_data = cataffinity[(cataffinity[column] == x) & (cataffinity[Column_2] == Y)]
    return filtered_data
def update_x_options(column, Column_2):
    x_dropdown.options = ['feature'] + column_values[column]
    y_dropdown.options = ['rropcf'] + column_values[Column_2]


def handle_filter_change(column, x, Column_2, Y):
    filtered_data = filter_data(column, x, Column_2, Y)
    display(filtered_data)
def handle_filter_change(column, x, Column_2, Y):
    global filtered_data
    filtered_data = filter_data(column, x, Column_2, Y)
    display(filtered_data)

def save_filtered_data_to_csv(change):
    file_path = change.new
    if save_dropdown.value == 'Yes':
        filtered_data = filter_data(column_dropdown.value, x_dropdown.value, y_column_dropdown.value, y_dropdown.value)
        filtered_data.to_csv(file_path, index=False)

# Create the dropdown widgets
column_dropdown = Dropdown(options=['feature'], value='feature', description='Column:')
x_dropdown = Dropdown(options=['category'] + column_values['feature'], value='category', description='X:')
y_column_dropdown = Dropdown(options=['rropcf'], value='rropcf', description='Column_2:')
y_dropdown = Dropdown(options=['boyfriend'] + column_values['rropcf'], value='boyfriend', description='Y:')
save_dropdown = widgets.Dropdown(options=['No', 'Yes'], value='No', description='Save filtered data to CSV?')
file_path_input = widgets.Text(value='', placeholder='Enter file path', description='File path:', disabled=False)
        
#display(path)
#path.observe(save_file_path, names='value')


display(save_dropdown)
display(file_path_input)
# Define the interactions between the dropdowns and the data filtering function
interacts = interact(handle_filter_change, column=column_dropdown, x=x_dropdown, Column_2=y_column_dropdown, Y=y_dropdown)

save_dropdown.observe(save_filtered_data_to_csv, names='value')
file_path_input.observe(save_filtered_data_to_csv, names='value')
# Out:
# Dropdown(description='Save filtered data to CSV?', options=('No', 'Yes'), value='No')
# Text(value='', description='File path:', placeholder='Enter file path')
# interactive(children=(Dropdown(description='Column:', options=('feature',), value='feature'), Dropdown(descrip…
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\Users\Mohij\anaconda3\lib\site-packages\ipywidgets\widgets\widget.py:676, in Widget._handle_msg(self, msg)
#     674         if 'buffer_paths' in data:
#     675             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676         self.set_state(state)
#     678 # Handle a state request.
#     679 elif method == 'request_state':
#
# File C:\Users\Mohij\anaconda3\lib\site-packages\ipywidgets\widgets\widget.py:540, in Widget.set_state(self, sync_data)
#     536 """Called when a state is received from the front-end."""
# ...
